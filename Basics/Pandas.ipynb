# %%
import pandas as pd

# %%
results = pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]}, index=["one","two"])

# %%
results.to_csv("results.csv")

# %%
pd.Series([30, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A')
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %%
housing_data = pd.read_csv("/content/sample_data/california_housing_test.csv")

# %%
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
housing_data.shape
# Out:
# (3000, 9)

# %%
housing_data.longitude
#or
housing_data["longitude"]
# Out:
# 0      -122.05
# 1      -118.30
# 2      -117.81
# 3      -118.36
# 4      -119.67
#          ...
# 2995   -119.86
# 2996   -118.14
# 2997   -119.70
# 2998   -117.12
# 2999   -119.63
# Name: longitude, Length: 3000, dtype: float64

# %%
            #columns ,rows
housing_data.longitude[:5]
#or
housing_data["longitude"][:5]
# Out:
# 0   -122.05
# 1   -118.30
# 2   -117.81
# 3   -118.36
# 4   -119.67
# Name: longitude, dtype: float64

# %%
                #rows,columns
housing_data.iloc[:5,:5]#index based
housing_data.iloc[[1,3,4],[1,3,5]]
# Out:
#    latitude  total_rooms  population
# 1     34.26       1510.0       809.0
# 3     33.82         67.0        49.0
# 4     36.33       1241.0       850.0

# %%
                #rows,columns
housing_data.loc[:5,"latitude"]#label based. also noticed about the slicing range
housing_data.loc[[1,3,4],["latitude", "population"]]
# Out:
#    latitude  population
# 1     34.26       809.0
# 3     33.82        49.0
# 4     36.33       850.0

# %%
housing_data.set_index("longitude")
# Out:
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.05       37.37                27.0       3885.0           661.0
# -118.30       34.26                43.0       1510.0           310.0
# -117.81       33.78                27.0       3589.0           507.0
# -118.36       33.82                28.0         67.0            15.0
# -119.67       36.33                19.0       1241.0           244.0
# ...             ...                 ...          ...             ...
# -119.86       34.42                23.0       1450.0           642.0
# -118.14       34.06                27.0       5257.0          1082.0
# -119.70       36.30                10.0        956.0           201.0
# -117.12       34.10                40.0         96.0            14.0
# -119.63       34.42                42.0       1765.0           263.0
#
#            population  households  median_income  median_house_value
# longitude
# ...

# %%
housing_data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
series1 = housing_data.total_rooms >=3000

# %%
series1
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2995    False
# 2996     True
# 2997    False
# 2998    False
# 2999    False
# Name: total_rooms, Length: 3000, dtype: bool

# %%
housing_data.loc[series1]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 17      -121.20     38.69                26.0       3077.0           607.0
# ...         ...       ...                 ...          ...             ...
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2987    -121.97     37.29                25.0       4096.0           743.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
series1 = ((housing_data.total_rooms >=3000) & (housing_data.median_income > 6)) | (housing_data.housing_median_age < 4)

# %%
series1
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
housing_data.loc[series1]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 19      -122.59     38.01                35.0       8814.0          1307.0
# 78      -118.75     34.17                18.0       6217.0           858.0
# 79      -122.47     37.99                22.0       7274.0          1002.0
# 102     -121.31     38.62                31.0       3114.0           430.0
# ...         ...       ...                 ...          ...             ...
# 2917    -122.59     38.04                25.0       3412.0           455.0
# 2925    -122.00     37.12                17.0       4413.0           672.0
# 2936    -119.75     36.87                 3.0      13802.0          2244.0
# 2963    -118.07     33.80                34.0       3486.0           507.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %%
# reviews.loc[reviews.country.isin(['Italy', 'France'])]

# %%
housing_data.isnull()
housing_data.notnull()
series1 = housing_data.total_rooms.notnull()
housing_data.total_rooms[series1]
housing_data[series1].total_rooms
# Out:
# 0       3885.0
# 1       1510.0
# 2       3589.0
# 3         67.0
# 4       1241.0
#          ...
# 2995    1450.0
# 2996    5257.0
# 2997     956.0
# 2998      96.0
# 2999    1765.0
# Name: total_rooms, Length: 3000, dtype: float64

# %%
housing_data["myIndex"] = range(len(housing_data), 0, -1)

# %%
housing_data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
housing_data.rename(columns={'median_house_value': 'median_valuation'})
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
housing_data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
housing_data.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#              longitude  latitude  housing_median_age  total_rooms  \
# firstEntry     -122.05     37.37                27.0       3885.0
# secondEntry    -118.30     34.26                43.0       1510.0
# 2              -117.81     33.78                27.0       3589.0
# 3              -118.36     33.82                28.0         67.0
# 4              -119.67     36.33                19.0       1241.0
# ...                ...       ...                 ...          ...
# 2995           -119.86     34.42                23.0       1450.0
# 2996           -118.14     34.06                27.0       5257.0
# 2997           -119.70     36.30                10.0        956.0
# 2998           -117.12     34.10                40.0         96.0
# 2999           -119.63     34.42                42.0       1765.0
#
#              total_bedrooms  population  households  median_income  \
# firstEntry            661.0      1537.0       606.0         6.6085
# ...

# %%
housing_data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
housing_data.rename_axis("houses", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields  longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# houses
# 0         -122.05     37.37                27.0       3885.0           661.0
# 1         -118.30     34.26                43.0       1510.0           310.0
# 2         -117.81     33.78                27.0       3589.0           507.0
# 3         -118.36     33.82                28.0         67.0            15.0
# 4         -119.67     36.33                19.0       1241.0           244.0
# ...           ...       ...                 ...          ...             ...
# 2995      -119.86     34.42                23.0       1450.0           642.0
# 2996      -118.14     34.06                27.0       5257.0          1082.0
# 2997      -119.70     36.30                10.0        956.0           201.0
# 2998      -117.12     34.10                40.0         96.0            14.0
# 2999      -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
# # when joining datasets that have same columns. so end of the all rows of the first then the second datasets rows start.
# canadian_youtube = pd.read_csv("../input/youtube-new/CAvideos.csv")
# british_youtube = pd.read_csv("../input/youtube-new/GBvideos.csv")

# pd.concat([canadian_youtube, british_youtube])

# %%
# #when they have common index.don't have the all same columns but the conjunction of comns are not null. so make the conjuction index then make it join by index
# left = canadian_youtube.set_index(['title', 'trending_date'])
# right = british_youtube.set_index(['title', 'trending_date'])

# left.join(right, lsuffix='_CAN', rsuffix='_UK')

# %%
housing_data.describe()
housing_data.population.describe()
housing_data.population.mean()
# housing_data.population.unique()
# housing_data.population.value_counts()
# Out:
# 1402.7986666666666

# %%
deviation_population = housing_data.population.mean()
housing_data["deviation_population"] = housing_data.population.map(lambda p: p - deviation_population)#returns a series
housing_data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
deviation_population = housing_data.population.mean()
def remean_points(row):
    row.population = row.population - deviation_population
    return row

housing_data.apply(remean_points, axis='columns')
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#        population  households  median_income  median_house_value
# ...

# %%
housing_data.iloc[housing_data.housing_median_age.idxmax()]
# Out:
# longitude               -122.420000
# latitude                  37.760000
# housing_median_age        52.000000
# total_rooms             3587.000000
# total_bedrooms          1030.000000
# population               856.201333
# households               979.000000
# median_income              2.540300
# median_house_value    250000.000000
# Name: 26, dtype: float64

# %%
bedsPerRoom = housing_data.total_bedrooms/housing_data.total_rooms
bedsPerRoom
# Out:
# 0       0.170142
# 1       0.205298
# 2       0.141265
# 3       0.223881
# 4       0.196616
#           ...
# 2995    0.442759
# 2996    0.205821
# 2997    0.210251
# 2998    0.145833
# 2999    0.149008
# Length: 3000, dtype: float64

# %%
passengers = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/test.csv")

# %%
passengers.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
passengers.groupby("Sex").Sex.size()
passengers.groupby("Sex").Sex.count()
# Out:
# Sex
# female    152
# male      266
# Name: Sex, dtype: int64

# %%
def edAg(age):
  if age<30:
    return "Learning"
  elif age<60:
    return "Working"
  return "Retired"

passengers["Education"] = passengers.Age.map(edAg)
passengers.groupby("Fare")

# %%
passengers
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# ...

# %%
passengers.groupby("Fare").Age.min()
passengers.groupby("Fare").Pclass.min()
# Out:
# Fare
# 0.0000      1
# 3.1708      3
# 6.4375      3
# 6.4958      3
# 6.9500      3
#            ..
# 227.5250    1
# 247.5208    1
# 262.3750    1
# 263.0000    1
# 512.3292    1
# Name: Pclass, Length: 169, dtype: int64

# %%
passengers.groupby("Education").Age.max()
# Out:
# Education
# Learning    29.0
# Retired     76.0
# Working     59.0
# Name: Age, dtype: float64

# %%
passengers.groupby("Fare").apply(lambda row: row.Age.max())
# Out:
# Fare
# 0.0000      49.0
# 3.1708       9.0
# 6.4375       NaN
# 6.4958      21.0
# 6.9500      30.0
#             ...
# 227.5250    47.0
# 247.5208    27.0
# 262.3750    61.0
# 263.0000    60.0
# 512.3292    58.0
# Length: 169, dtype: float64

# %%
temp = passengers.groupby(["Education","Embarked"]).apply(lambda row: row.loc[passengers.Sex=='male', ["PassengerId",	"Pclass"	,"Name",	"Sex",	"Age"	,"SibSp"	,"Parch"	,"Ticket"	,"Fare",	"Cabin"]])
tempindex = temp.index
print(type(tempindex))
temp = temp.reset_index()
temp
passengers.groupby("Embarked").apply(lambda x:x.loc[passengers.Age > 0])
# Out:
# <class 'pandas.core.indexes.multi.MultiIndex'>
#     Education Embarked  level_2  PassengerId  Pclass  \
# 0    Learning        C       17          909       3
# 1    Learning        C       23          915       1
# 2    Learning        C       27          919       3
# 3    Learning        C       35          927       3
# 4    Learning        C       51          943       2
# ..        ...      ...      ...          ...     ...
# 261   Working        S      378         1270       1
# 262   Working        S      387         1279       2
# 263   Working        S      393         1285       2
# 264   Working        S      401         1293       2
# 265   Working        S      415         1307       3
#
#                                                  Name   Sex   Age  SibSp  \
# 0                                   Assaf, Mr. Gerios  male  21.0      0
# 1                     Williams, Mr. Richard Norris II  male  21.0      0
# ...

# %%
passengers.groupby("Education").Fare.agg([len, min, max])
# Out:
#            len     min       max
# Education
# Learning   185  3.1708  263.0000
# Retired    100  0.0000  263.0000
# Working    133  0.0000  512.3292

# %%
passengers.sort_values(by='Age', ascending=False)
# Out:
#      PassengerId  Pclass                                               Name  \
# 96           988       1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 81           973       1                                 Straus, Mr. Isidor
# 236         1128       1                           Warren, Mr. Frank Manley
# 305         1197       1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 179         1071       1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
passengers.loc[passengers.Age<30].sort_index()
# Out:
#      PassengerId  Pclass                                          Name  \
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                    Svensson, Mr. Johan Cervin
# 7            899       2                  Caldwell, Mr. Albert Francis
# 8            900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# ..           ...     ...                                           ...
# 403         1295       1                        Carrau, Mr. Jose Pedro
# 405         1297       2  Nourney, Mr. Alfred (Baron von Drachstedt")"
# 406         1298       2                     Ware, Mr. William Jeffery
# 409         1301       3                     Peacock, Miss. Treasteall
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked  \
# ...

# %%
passengers.loc[passengers.Age<30].sort_index()
passengers.sort_values(by=["Embarked", "Age"])
# Out:
#      PassengerId  Pclass                             Name     Sex  Age  SibSp  \
# 296         1188       2            Laroche, Miss. Louise  female  1.0      1
# 80           972       3             Boulos, Master. Akar    male  6.0      1
# 196         1088       1  Spedden, Master. Robert Douglas    male  6.0      0
# 161         1053       3   Touma, Master. Georges Youssef    male  7.0      1
# 283         1175       3       Touma, Miss. Maria Youssef  female  9.0      1
# ..           ...     ...                              ...     ...  ...    ...
# 365         1257       3   Sage, Mrs. John (Annie Bullen)  female  NaN      1
# 382         1274       3       Risien, Mrs. Samuel (Emma)  female  NaN      0
# 384         1276       2   Wheeler, Mr. Edwin Frederick""    male  NaN      0
# 413         1305       3               Spector, Mr. Woolf    male  NaN      0
# 416         1308       3              Ware, Mr. Frederick    male  NaN      0
#
# ...

# %%
passengers.dtypes
# Out:
# PassengerId      int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Education       object
# dtype: object

# %%
passengers.Age.dtypes
# Out:
# dtype('float64')

# %%
passengers.Parch.astype("int64")
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    0
# 415    0
# 416    0
# 417    1
# Name: Parch, Length: 418, dtype: int64

# %%
pd.isnull(passengers.Age)
passengers.loc[pd.isnull(passengers.Age)]
# Out:
#      PassengerId  Pclass                                               Name  \
# 10           902       3                                   Ilieff, Mr. Ylio
# 22           914       1               Flegenheim, Mrs. Alfred (Antoinette)
# 29           921       3                                  Samaan, Mr. Elias
# 33           925       3  Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"
# 36           928       3                                Roth, Miss. Sarah A
# ..           ...     ...                                                ...
# 408         1300       3                    Riordan, Miss. Johanna Hannah""
# 410         1302       3                             Naughton, Miss. Hannah
# 413         1305       3                                 Spector, Mr. Woolf
# 416         1308       3                                Ware, Mr. Frederick
# 417         1309       3                           Peter, Master. Michael J
#
# ...

# %%
passengers.Age = passengers.Age.fillna("unknown")

# %%
passengers.iloc[10]
# Out:
# PassengerId                 902
# Pclass                        3
# Name           Ilieff, Mr. Ylio
# Sex                        male
# Age                     unknown
# SibSp                         0
# Parch                         0
# Ticket                   349220
# Fare                     7.8958
# Cabin                       NaN
# Embarked                      S
# Education               Retired
# Name: 10, dtype: object

# %%
passengers.Age = passengers.Age.replace("unknown","DNK")

# %%
passengers.Age.unique()
# Out:
# array([34.5, 47.0, 62.0, 27.0, 22.0, 14.0, 30.0, 26.0, 18.0, 21.0, 'DNK',
#        46.0, 23.0, 63.0, 24.0, 35.0, 45.0, 55.0, 9.0, 48.0, 50.0, 22.5,
#        41.0, 33.0, 18.5, 25.0, 39.0, 60.0, 36.0, 20.0, 28.0, 10.0, 17.0,
#        32.0, 13.0, 31.0, 29.0, 28.5, 32.5, 6.0, 67.0, 49.0, 2.0, 76.0,
#        43.0, 16.0, 1.0, 12.0, 42.0, 53.0, 26.5, 40.0, 61.0, 60.5, 7.0,
#        15.0, 54.0, 64.0, 37.0, 34.0, 11.5, 8.0, 0.33, 38.0, 57.0, 40.5,
#        0.92, 19.0, 36.5, 0.75, 0.83, 58.0, 0.17, 59.0, 14.5, 44.0, 5.0,
#        51.0, 3.0, 38.5], dtype=object)
